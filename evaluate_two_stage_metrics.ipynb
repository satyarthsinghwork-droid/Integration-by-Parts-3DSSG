# %% [markdown]
# # Evaluate the included best two-stage checkpoint
# Run this after the official database has been prepared.

# %%
from pathlib import Path
from mtp_pipeline.protocol_run_v6 import default_layout, run_official_evaluation

SCAN_ROOT = Path(r"D:\\path\\to\\3RScan")  # Change this only.
layout = default_layout(SCAN_ROOT, Path.cwd())
checkpoint = Path.cwd() / "artifacts" / "checkpoints" / "graph_best_official_proxy.pt"
run_official_evaluation(layout, checkpoint, device="cuda")
